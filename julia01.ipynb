# %% [markdown]
# # Curso de Julia
# ## Diego Tapias

# %% [markdown]
# - Julia was initially designed with scientific computing in mind

# %%
using PyCall
@pyimport IPython
@pyimport IPython.display as dpl
@pyimport wand.image as wima

# %%
dpl.Image(filename="../../Pictures/juliabenchmarks.png")
# Out:
# PyObject <IPython.core.display.Image object>
